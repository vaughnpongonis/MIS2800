# %% [markdown]
# <a href="https://colab.research.google.com/github/vaughnpongonis/MIS2800/blob/main/HW3_WK4_Pongonis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade pandas ipython-sql prettytable==3.10.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 62.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 56.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: prettytable
#     Found existing installation: prettytable 3.17.0
#     Uninstalling prettytable-3.17.0:
#       Successfully uninstalled prettytable-3.17.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.0 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.0 which is incompatible.
# ...

# %%
# !pip install ipython-sql
print("ipython sql installed")
# Out:
# ...
# ipython sql installed

# %%
# %load_ext sql

# %%
import sqlite3
print("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
conn = sqlite3.connect('AdCampaigns2026.db')
print("database created")
# Out:
# database created

# %%
# %sql sqlite:///AdCampaigns2026.db

# %% [markdown]
# Mistakes Fixed

# %%
# %%sql
# CREATE TABLE marketing_brands (
#   brand_id INTEGER PRIMARY KEY,
#   brand_name TEXT,
#   brand_type TEXT,
#   brand_budget INTEGER
# ) STRICT;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# []

# %%
# %%sql
# DELETE FROM marketing_brands;
# INSERT INTO marketing_brands (brand_id, brand_name, brand_type, brand_budget)
# VALUES
#   (1, 'Doritos', 'Snacks', 7000000),
#   (2, 'AWS', 'Technology', 15000000),
#   (3, 'Pepsi', 'Beverages', 2000000),
#   (4, 'He_Gets_Us', 'Religious', 1000000),
#   (5, 'Dr_Pepper', 'Beverages', 5000000),
#   (6, 'IBM', 'Technology', 100000),
#   (7, 'Google', 'Technology', 8000000);
# Out:
#  * sqlite:///AdCampaigns2026.db
# 7 rows affected.
# 7 rows affected.
# []

# %%
# %%sql
# SELECT * FROM marketing_brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (2, 'AWS', 'Technology', 15000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (6, 'IBM', 'Technology', 100000),
#  (7, 'Google', 'Technology', 8000000)]

# %%
# %%sql
# SELECT brand_name, brand_budget FROM marketing_brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos', 7000000),
#  ('AWS', 15000000),
#  ('Pepsi', 2000000),
#  ('He_Gets_Us', 1000000),
#  ('Dr_Pepper', 5000000),
#  ('IBM', 100000),
#  ('Google', 8000000)]

# %%
# %%sql
# SELECT * FROM marketing_brands
# WHERE brand_type = 'Religious';
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(4, 'He_Gets_Us', 'Religious', 1000000)]

# %%
# %%sql
# SELECT brand_name FROM marketing_brands
# WHERE brand_budget > 5000000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos',), ('AWS',), ('Google',)]

# %%
# %%sql
# SELECT * FROM marketing_brands WHERE brand_budget > 7000000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(2, 'AWS', 'Technology', 15000000), (7, 'Google', 'Technology', 8000000)]

# %%
# %%sql
# SELECT * FROM marketing_brands
# ORDER BY brand_budget DESC;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(2, 'AWS', 'Technology', 15000000),
#  (7, 'Google', 'Technology', 8000000),
#  (1, 'Doritos', 'Snacks', 7000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (6, 'IBM', 'Technology', 100000)]

# %%
# %%sql
# SELECT * FROM marketing_brands
# WHERE brand_type = 'Snacks' OR brand_type = 'Beverages';
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000)]

# %%
# %%sql
# SELECT * FROM marketing_brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (2, 'AWS', 'Technology', 15000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (6, 'IBM', 'Technology', 100000),
#  (7, 'Google', 'Technology', 8000000)]

# %% [markdown]
# How did you fix the error in Block #1? Answer:
# 2. How did you fix the error in Block #2? Answer:
# 3. How did you fix the error in Block #3? Answer:
# 4. How did you fix the error in Block #4? Answer:
# 5. How did you fix the error in Block #5? Answer:
# 6. How did you fix the error in Block #6? Answer:
# 7. How did you fix the error in Block #7? Answer:
# 8. How did you fix the error in Block #8? Answer:
# 9. How did you fix the error in Block #9? Answer:
# 10. How did you fix the error in Block #10? Answer:

# %% [markdown]
# 1. the create statement was missing in the table.
# 2. was mising the INTO beforr insert.
# 3. was missing the * symbol
# 4. was missing the specific column to show
# 5. was missing the * symbol
# 6. was a typo it was bud instead of budget
# 7. was missing the %%sql
# 8. was missing WHERE before bdrnd_type
# 9. was missing the * symbol
# 10. wasmissing %%sql
